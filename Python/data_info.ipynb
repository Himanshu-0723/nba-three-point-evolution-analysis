# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Cleaned\team_stats_clean.csv')
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'gameId', 'teamId', 'opponentTeamId', 'home', 'win',
#        'teamScore', 'opponentScore', 'assists', 'blocks', 'steals',
#        'fieldGoalsAttempted', 'fieldGoalsMade', 'threePointersAttempted',
#        'threePointersMade', 'freeThrowsAttempted', 'freeThrowsMade',
#        'reboundsDefensive', 'reboundsOffensive', 'reboundsTotal',
#        'foulsPersonal', 'turnovers', 'plusMinusPoints', 'numMinutes',
#        'q1Points', 'q2Points', 'q3Points', 'q4Points', 'benchPoints',
#        'biggestLead', 'biggestScoringRun', 'leadChanges', 'pointsFastBreak',
#        'pointsFromTurnovers', 'pointsInThePaint', 'pointsSecondChance',
#        'timesTied', 'timeoutsRemaining', 'seasonWins', 'seasonLosses',
#        'coachId', 'gameDateTime', 'season', 'team', 'opponentTeam', 'FG_pct',
#        'FT_pct', '3P_pct'],
#       dtype='str')

# %%
games = pd.read_csv(r"C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Raw\Games.csv")
players = pd.read_csv(r"C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Raw\Players.csv")
players_stats = pd.read_csv(r"C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Raw\PlayerStatistics.csv")
team_history = pd.read_csv(r"C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Raw\TeamHistories.csv")
team_stats = pd.read_csv(r"C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Raw\TeamStatistics.csv")
# Out:
# C:\Users\himan\AppData\Local\Temp\ipykernel_14064\3209027149.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   games = pd.read_csv(r"C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Raw\Games.csv")
# C:\Users\himan\AppData\Local\Temp\ipykernel_14064\3209027149.py:3: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_stats = pd.read_csv(r"C:\Users\himan\Downloads\DA\Project\NBA_Analytics\Data\Raw\PlayerStatistics.csv")

# %%
print(games.columns)
games.shape
# Out:
# Index(['gameId', 'gameDateTimeEst', 'hometeamCity', 'hometeamName',
#        'hometeamId', 'awayteamCity', 'awayteamName', 'awayteamId', 'homeScore',
#        'awayScore', 'winner', 'gameType', 'attendance', 'arenaId', 'gameLabel',
#        'gameSubLabel', 'seriesGameNumber'],
#       dtype='object')
# (72504, 17)

# %%
print(players.columns)
players.shape
# Out:
# Index(['personId', 'firstName', 'lastName', 'birthdate', 'lastAttended',
#        'country', 'height', 'bodyWeight', 'guard', 'forward', 'center',
#        'draftYear', 'draftRound', 'draftNumber'],
#       dtype='object')
# (6681, 14)

# %%
print(players_stats.columns)
players_stats.shape
# Out:
# Index(['firstName', 'lastName', 'personId', 'gameId', 'gameDateTimeEst',
#        'playerteamCity', 'playerteamName', 'opponentteamCity',
#        'opponentteamName', 'gameType', 'gameLabel', 'gameSubLabel',
#        'seriesGameNumber', 'win', 'home', 'numMinutes', 'points', 'assists',
#        'blocks', 'steals', 'fieldGoalsAttempted', 'fieldGoalsMade',
#        'fieldGoalsPercentage', 'threePointersAttempted', 'threePointersMade',
#        'threePointersPercentage', 'freeThrowsAttempted', 'freeThrowsMade',
#        'freeThrowsPercentage', 'reboundsDefensive', 'reboundsOffensive',
#        'reboundsTotal', 'foulsPersonal', 'turnovers', 'plusMinusPoints'],
#       dtype='object')
# (1644443, 35)

# %%
print(team_history.columns)
team_history.shape
# Out:
# Index(['teamId', 'teamCity', 'teamName', 'teamAbbrev', 'seasonFounded',
#        'seasonActiveTill', 'league'],
#       dtype='object')
# (140, 7)

# %%
print(team_stats.columns)
team_stats.shape
# Out:
# Index(['gameId', 'gameDateTimeEst', 'teamCity', 'teamName', 'teamId',
#        'opponentTeamCity', 'opponentTeamName', 'opponentTeamId', 'home', 'win',
#        'teamScore', 'opponentScore', 'assists', 'blocks', 'steals',
#        'fieldGoalsAttempted', 'fieldGoalsMade', 'fieldGoalsPercentage',
#        'threePointersAttempted', 'threePointersMade',
#        'threePointersPercentage', 'freeThrowsAttempted', 'freeThrowsMade',
#        'freeThrowsPercentage', 'reboundsDefensive', 'reboundsOffensive',
#        'reboundsTotal', 'foulsPersonal', 'turnovers', 'plusMinusPoints',
#        'numMinutes', 'q1Points', 'q2Points', 'q3Points', 'q4Points',
#        'benchPoints', 'biggestLead', 'biggestScoringRun', 'leadChanges',
#        'pointsFastBreak', 'pointsFromTurnovers', 'pointsInThePaint',
#        'pointsSecondChance', 'timesTied', 'timeoutsRemaining', 'seasonWins',
#        'seasonLosses', 'coachId'],
#       dtype='object')
# (145008, 48)
